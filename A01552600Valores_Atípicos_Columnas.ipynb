# %% [markdown]
# <a href="https://colab.research.google.com/github/edgardiaziba/Actividad3_Valores_atipicos_/blob/main/A01552600Valores_At%C3%ADpicos_Columnas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5420bec5-f9fe-47d9-8821-51a39423038a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5420bec5-f9fe-47d9-8821-51a39423038a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#carga de un archivo csv sin ídices
df=pd.read_csv('Valores_sin_nulos.csv')
df.head()
# Out:
#    Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0           0    01/01/2017                    27858.9
# 1           1    01/02/2017                    25994.2
# 2           2    01/03/2017                    27780.0
# 3           3    01/04/2017                    29134.3
# 4           4    01/05/2017                    27969.0
#
#    ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                    27477.3                 27858872.08   27591730.13
# 1                    25223.4                 25994200.17   25749179.40
# 2                    26334.3                 27780006.52   27472228.72
# 3                    27045.9                 29134272.22   28827479.49
# 4                    25631.9                 27969004.68   27569311.41
#
#    canales_on_line  ventas_totales_medio_pago      efectivo  tarjetas_debito  \
# 0       267141.956                27858872.08  1.023010e+07      6864575.384
# ...

# %%
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                             0
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# ...

# %%
df1=df.copy()

# %%
valores_nulos=df1.isnull().sum().sum()
valores_nulos
# Out:
# 0

# %% [markdown]
# #1

# %%
#realizamos el diagrama de caja o bigote
fig = plt.figure(figsize =(10,6))
plt.boxplot(df1['ventas_precios_constantes'])
plt.title('Outliers de ventas_precios_constantes')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estándar. Encuentro los valores extremos
y=df1['ventas_precios_constantes']
Limite_superior= y.mean() + 3*y.std()
Limite_inferior= y.mean() - 3*y.std()
print('Limite superior permitido', Limite_superior)
print('Limite inferior permitido', Limite_inferior)
# Out:
# Limite superior permitido 40022.90598479884
# Limite inferior permitido 12104.484784431932

# %%
#Encontramos outliers
outliers = df1[(y>Limite_superior) | (y<Limite_inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 42          42    01/07/2020                   211140.7
# 60          60    01/01/2022                   154517.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 42                    50791.4                8.114070e+07  7.641372e+07
# 60                    45463.4                1.545171e+08  1.496976e+08
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 42      4726974.457               8.114070e+07  24935747.29      22143208.63
# 60      4819479.554               1.545171e+08  46962602.22      46053650.13
#
#     ...      almacen    panaderia       lacteos        carnes  \
# 42  ...  23393038.41  2630487.791  9.592798e+06  8.463266e+06
# 60  ...  37505172.62  4860317.680  1.610477e+07  1.740849e+07
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                    5.189425e+05
# ...

# %%
#obtenemos datos limpios
data_clean_ventas_precios_constantes = df1[(y<=Limite_superior) & (y>=Limite_inferior)]
data_clean_ventas_precios_constantes
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 59          59    01/12/2021                   183983.2
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# #2

# %%
#realizamos el diagrama de caja o bigote
fig = plt.figure(figsize =(10,6))
plt.boxplot(df1['otros'])
plt.title('Outliers de otros')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estándar. Encuentro los valores extremos
y=df1['otros']
Limite_superior= y.mean() + 3*y.std()
Limite_inferior= y.mean() - 3*y.std()
print('Limite superior permitido', Limite_superior)
print('Limite inferior permitido', Limite_inferior)
# Out:
# Limite superior permitido 15434892.939450309
# Limite inferior permitido -3882885.8799426183

# %%
#Encontramos outliers
outliers = df1[(y>Limite_superior) | (y<Limite_inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#obtenemos datos limpios
data_clean_otros = df1[(y<=Limite_superior) & (y>=Limite_inferior)]
data_clean_otros
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# 3

# %%
#realizamos el diagrama de caja o bigote
fig = plt.figure(figsize =(10,6))
plt.boxplot(df1['indumentaria_calzado_textiles_hogar'])
plt.title('Outliers de indumentaria_calzado_textiles_hogar	')
plt.show() #dibujamos el diagrama
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#Método aplicando desviación estándar. Encuentro los valores extremos
y=df1['indumentaria_calzado_textiles_hogar']
Limite_superior= y.mean() + 3*y.std()
Limite_inferior= y.mean() - 3*y.std()
print('Limite superior permitido', Limite_superior)
print('Limite inferior permitido', Limite_inferior)
# Out:
# Limite superior permitido 5075140.00277631
# Limite inferior permitido -1409995.7947270796

# %%
#Encontramos outliers
outliers = df1[(y>Limite_superior) | (y<Limite_inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 64           6314109.47                     1779482.857
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 64                    23578638.71                          5213152.564
#
#     electronicos_articulos_hogar        otros
# 64                   12039595.55  12349980.06
#
# [1 rows x 25 columns]

# %%
#obtenemos datos limpios
data_indumentaria_calzado_textiles_hogar = df1[(y<=Limite_superior) & (y>=Limite_inferior)]
data_indumentaria_calzado_textiles_hogar
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 59          59    01/12/2021                   183983.2
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# 4

# %%
#realizamos el diagrama de caja o bigote
fig = plt.figure(figsize =(10,6))
plt.boxplot(df1['alimentos_preparados_rotiseria'])
plt.title('Outliers de verduleria_fruteria')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estándar. Encuentro los valores extremos
y=df1['alimentos_preparados_rotiseria']
Limite_superior= y.mean() + 2.5*y.std()
Limite_inferior= y.mean() - 2.5*y.std()
print('Limite superior permitido', Limite_superior)
print('Limite inferior permitido', Limite_inferior)
# Out:
# Limite superior permitido 1612873.491538451
# Limite inferior permitido -233700.92161845125

# %%
#Encontramos outliers
outliers = df1[(y>Limite_superior) | (y<Limite_inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
# 63      4144283.743                177148082.8  53189998.68      50063972.79
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
# ...

# %%
#obtenemos datos limpios
data_alimentos_preparados_rotiseria = df1[(y<=Limite_superior) & (y>=Limite_inferior)]
data_alimentos_preparados_rotiseria
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 57          57    01/10/2021                   140487.5
# 58          58    01/11/2021                   141702.0
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# 5

# %%
#realizamos el diagrama de caja o bigote
fig = plt.figure(figsize =(10,6))
plt.boxplot(df1['lacteos'])
plt.title('Outliers de verduleria_fruteria')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estándar. Encuentro los valores extremos
y=df1['lacteos']
Limite_superior= y.mean() + 2.5*y.std()
Limite_inferior= y.mean() - 2.5*y.std()
print('Limite superior permitido', Limite_superior)
print('Limite inferior permitido', Limite_inferior)
# Out:
# Limite superior permitido 19896951.851867568
# Limite inferior permitido -3516006.7008829527

# %%
#Encontramos outliers
outliers = df1[(y>Limite_superior) | (y<Limite_inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 64           6314109.47                     1779482.857
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 64                    23578638.71                          5213152.564
#
#     electronicos_articulos_hogar        otros
# 64                   12039595.55  12349980.06
#
# [1 rows x 25 columns]

# %%
#obtenemos datos limpios
data_lacteos = df1[(y<=Limite_superior) & (y>=Limite_inferior)]
data_lacteos
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 59          59    01/12/2021                   183983.2
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# 6

# %%
#realizamos el diagrama de caja o bigote
fig = plt.figure(figsize =(10,6))
plt.boxplot(df1['panaderia'])
plt.title('Outliers de panaderia')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estándar. Encuentro los valores extremos
y=df1['panaderia']
Limite_superior= y.mean() + 2.5*y.std()
Limite_inferior= y.mean() - 2.5*y.std()
print('Limite superior permitido', Limite_superior)
print('Limite inferior permitido', Limite_inferior)
# Out:
# Limite superior permitido 6180212.324549198
# Limite inferior permitido -1093731.9255799665

# %%
#Encontramos outliers
outliers = df1[(y>Limite_superior) | (y<Limite_inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 63      4144283.743                177148082.8  53189998.68      50063972.79
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 63  ...  49991675.91  6746166.557  19309461.59  22877841.24
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 63          6510665.781                     1719458.547
# ...

# %%
#obtenemos datos limpios
data_panaderia = df1[(y<=Limite_superior) & (y>=Limite_inferior)]
data_panaderia
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 58          58    01/11/2021                   141702.0
# 59          59    01/12/2021                   183983.2
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# 7

# %%
#realizamos el diagrama de caja o bigote
fig = plt.figure(figsize =(10,6))
plt.boxplot(df1['tarjetas_debito'])
plt.title('Outliers de tarjetas_debito')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estándar. Encuentro los valores extremos
y=df1['tarjetas_debito']
Limite_superior= y.mean() + 2.5*y.std()
Limite_inferior= y.mean() - 2.5*y.std()
print('Limite superior permitido', Limite_superior)
print('Limite inferior permitido', Limite_inferior)
# Out:
# Limite superior permitido 52381151.682539165
# Limite inferior permitido -12024955.828662246

# %%
#Encontramos outliers
outliers = df1[(y>Limite_superior) | (y<Limite_inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#obtenemos datos limpios
data_tarjetas_debito = df1[(y<=Limite_superior) & (y>=Limite_inferior)]
data_tarjetas_debito
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %% [markdown]
# Se encontraron solo 7 columnas con valores atípicos.

# %%
#convertir archivo filtrado a CSV
data_clean_ventas_precios_constantes.to_csv("EdgarO1.csv")
data_clean_otros.to_csv("EdgarO2.csv")
data_indumentaria_calzado_textiles_hogar.to_csv("EdgarO3.csv")
data_alimentos_preparados_rotiseria.to_csv("EdgarO4.csv")
data_lacteos.to_csv("EdgarO5.csv")
data_panaderia.to_csv("EdgarO6.csv")
data_tarjetas_debito.to_csv("EdgarO7.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files

files.download("EdgarO1.csv")
files.download("EdgarO2.csv")
files.download("EdgarO3.csv")
files.download("EdgarO4.csv")
files.download("EdgarO5.csv")
files.download("EdgarO6.csv")
files.download("EdgarO7.csv")
